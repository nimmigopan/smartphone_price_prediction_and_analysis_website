# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cleaned_data1.csv')

# %%
pd.set_option('display.max_rows', None)

df.drop(['Unnamed: 0'], axis=1,inplace = True)

# %%
df
# Out:
#                                                  model   price  rating  \
# 0                                   Xiaomi Redmi 12 5G   11999    75.0
# 1               Xiaomi Redmi 12 5G (6 GB RAM + 128 GB)   13499    77.0
# 2                 Xiaomi Redmi 12 5G (8GB RAM + 256GB)   15499    80.0
# 3                            OnePlus Nord CE 3 Lite 5G   19999    85.0
# 4                                Samsung Galaxy F34 5G   18999    83.0
# 5                                 OnePlus Nord CE 3 5G   26999    84.0
# 6                        Vivo T2x 5G (6GB RAM + 128GB)   13999    78.0
# 7                                           Realme C53    9999    75.0
# 8                                  Motorola Edge 40 5G   29999    87.0
# 9                                         OPPO Reno 10   32999    88.0
# 10                                       Realme 11 Pro   23599    85.0
# 11                            Samsung Galaxy S21 FE 5G   39999    87.0
# ...

# %%
df.shape
# Out:
# (709, 11)

# %%
df.drop([331,355,468,484,668,440],inplace = True) #ignoring some more feature phones

# %%
df
# Out:
#                                                  model   price  rating  \
# 0                                   Xiaomi Redmi 12 5G   11999    75.0
# 1               Xiaomi Redmi 12 5G (6 GB RAM + 128 GB)   13499    77.0
# 2                 Xiaomi Redmi 12 5G (8GB RAM + 256GB)   15499    80.0
# 3                            OnePlus Nord CE 3 Lite 5G   19999    85.0
# 4                                Samsung Galaxy F34 5G   18999    83.0
# 5                                 OnePlus Nord CE 3 5G   26999    84.0
# 6                        Vivo T2x 5G (6GB RAM + 128GB)   13999    78.0
# 7                                           Realme C53    9999    75.0
# 8                                  Motorola Edge 40 5G   29999    87.0
# 9                                         OPPO Reno 10   32999    88.0
# 10                                       Realme 11 Pro   23599    85.0
# 11                            Samsung Galaxy S21 FE 5G   39999    87.0
# ...

# %%
df.shape
# Out:
# (703, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 703 entries, 0 to 708
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   model             703 non-null    object
#  1   price             703 non-null    int64
#  2   rating            633 non-null    float64
#  3   sim               703 non-null    object
#  4   processor         703 non-null    object
#  5   ram_rom           703 non-null    object
#  6   battery           703 non-null    object
#  7   display           703 non-null    object
#  8   camera            703 non-null    object
#  9   memory_card       703 non-null    object
#  10  operating_system  703 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 65.9+ KB

# %%
df.isnull().sum()      # missing values in 'rating'
# Out:
# model                0
# price                0
# rating              70
# sim                  0
# processor            0
# ram_rom              0
# battery              0
# display              0
# camera               0
# memory_card          0
# operating_system     0
# dtype: int64

# %%
df['model'].value_counts()
# Out:
# Xiaomi Redmi 12 5G                                    1
# Samsung Galaxy A04s (4GB RAM + 128GB)                 1
# Xiaomi Redmi Note 10 Pro                              1
# Samsung Galaxy A52                                    1
# Xiaomi Redmi 9                                        1
# itel S23 (4GB RAM +128 GB)                            1
# Samsung Galaxy A14 4G (4GB RAM + 128 GB)              1
# Tecno Spark Go 2023 (3GB RAM + 64GB)                  1
# Realme C33 2023 (4GB RAM + 128GB)                     1
# Nokia C22                                             1
# Samsung Galaxy A04e (4GB RAM + 128GB)                 1
# Xiaomi Mi 10T 5G (8GB RAM + 128GB)                    1
# Tecno Pova 4                                          1
# Apple iPhone 14 Plus (512GB)                          1
# Apple iPhone 14 Pro Max (512GB)                       1
# OPPO A77 (4GB RAM + 128 GB)                           1
# OnePlus 10T (12GB RAM + 256GB)                        1
# ...

# %%
df['price'].value_counts()
# Out:
# 9999      18
# 8999      15
# 14999     15
# 10999     14
# 18999     13
# 7999      12
# 10499     11
# 6999      10
# 8499      10
# 15999      9
# 17999      9
# 16999      9
# 20999      9
# 13999      9
# 26999      9
# 9499       9
# 12999      8
# 11999      8
# 12990      8
# 24999      7
# 15499      7
# 29999      7
# 6499       7
# 14499      7
# 21999      7
# 23999      7
# 28999      6
# 6299       6
# 12499      6
# 11499      6
# 5999       6
# 13499      6
# 19999      6
# 36999      5
# 37999      5
# 49999      5
# 16499      5
# 22999      5
# 89999      4
# 15990      4
# 6599       4
# 27999      4
# 44999      4
# 34999      4
# 17990      4
# 7699       4
# 59999      4
# 39999      4
# 79999      3
# 35999      3
# 30999      3
# 54999      3
# 15490      3
# 10990      3
# 9299       3
# 4999       3
# 13990      3
# 7299       3
# 8799       3
# 22990      3
# 17499      3
# 59990      2
# 25999      2
# 42999      2
# 29990      2
# 69999      2
# ...

# %%
df['rating'].value_counts()
# Out:
# 75.0    43
# 82.0    43
# 84.0    40
# 83.0    35
# 85.0    33
# 86.0    30
# 89.0    29
# 80.0    27
# 79.0    27
# 81.0    25
# 87.0    23
# 88.0    23
# 74.0    23
# 61.0    21
# 77.0    21
# 71.0    21
# 66.0    18
# 70.0    17
# 78.0    15
# 65.0    14
# 60.0    13
# 73.0    12
# 72.0    12
# 64.0    12
# 76.0    12
# 68.0    11
# 69.0    11
# 62.0    11
# 67.0     7
# 63.0     4
# Name: rating, dtype: int64

# %%
df['sim'].value_counts() # tidiness issue is there
# Out:
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                         288
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                147
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                      89
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster              55
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster          50
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                     26
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster     21
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC           14
# Dual Sim, 3G, 4G, Wi-Fi                                  6
# Single Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC          2
# Dual Sim, 3G, 4G, VoLTE                                  2
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                1
# Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                    1
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster          1
# Name: sim, dtype: int64

# %%
df['processor'].value_counts()
# Out:
# Helio G35, Octa Core, 2.3 GHz Processor                  19
# Snapdragon 680, Octa Core, 2.4 GHz Processor             17
# Bionic A15, Hexa Core, 3.22 GHz Processor                17
# Helio A22, Quad Core, 2 GHz Processor                    15
# Snapdragon 695, Octa Core, 2.2 GHz Processor             15
# Helio P35, Octa Core, 2.3 GHz Processor                  14
# Quad Core, 1.3 GHz Processor                             12
# Helio G88, Octa Core, 2 GHz Processor                    12
# Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor         12
# Dimensity 1080, Octa Core, 2.6 GHz Processor             12
# Snapdragon 778G, Octa Core, 2.4 GHz Processor            11
# Snapdragon  680, Octa Core, 2.4 GHz Processor            11
# Dimensity 7050, Octa Core, 2.6 GHz Processor             10
# Helio  G85, Octa Core, 2 GHz Processor                   10
# Dimensity 6020, Octa Core, 2.2 GHz Processor             10
# Dimensity  810 5G, Octa Core, 2.4 GHz Processor          10
# ...

# %%
df['ram_rom'].value_counts() #some rows contain only rom. RAM is in GB. ROM is in GB & TB. (consistent issue)
# Out:
# 8 GB RAM, 128 GB inbuilt     143
# 4 GB RAM, 64 GB inbuilt      137
# 6 GB RAM, 128 GB inbuilt     114
# 8 GB RAM, 256 GB inbuilt      57
# 4 GB RAM, 128 GB inbuilt      53
# 12 GB RAM, 256 GB inbuilt     48
# 3 GB RAM, 32 GB inbuilt       31
# 2 GB RAM, 32 GB inbuilt       30
# 6 GB RAM, 64 GB inbuilt       23
# 3 GB RAM, 64 GB inbuilt       10
# 2 GB RAM, 64 GB inbuilt        9
# 6 GB RAM, 256 GB inbuilt       6
# 6 GB RAM, 512 GB inbuilt       6
# 16 GB RAM, 256 GB inbuilt      5
# 12 GB RAM, 512 GB inbuilt      4
# 6 GB RAM, 1 TB inbuilt         4
# 2 GB RAM, 16 GB inbuilt        4
# 8 GB RAM, 512 GB inbuilt       3
# 4 GB RAM, 32 GB inbuilt        3
# 4 GB RAM, 512 GB inbuilt       2
# 4 GB RAM, 256 GB inbuilt       2
# 12 GB RAM, 1 TB inbuilt        2
# 64 GB inbuilt                  1
# 12 GB RAM, 128 GB inbuilt      1
# 256 GB inbuilt                 1
# 128 GB inbuilt                 1
# 18 GB RAM, 512 GB inbuilt      1
# 1 GB RAM, 8 GB inbuilt         1
# ...

# %%
df['battery'].value_counts() 
# in 6 rows 'display' info is given instead of battery info.   (validity issue)
# consistent issues in some battery info
# eg) --- mAh Battery
#     --- mAh Battery with Fast Charging
#     --- mAh Battery with ---W Fast Charging
# Out:
# 5000 mAh Battery with 33W Fast Charging                76
# 5000 mAh Battery                                       75
# 5000 mAh Battery with 18W Fast Charging                61
# 5000 mAh Battery with 10W Fast Charging                46
# 5000 mAh Battery with 67W Fast Charging                27
# 5000 mAh Battery with 25W Fast Charging                26
# 6000 mAh Battery with 18W Fast Charging                23
# 4000 mAh Battery                                       19
# 5000 mAh Battery with 15W Fast Charging                19
# 5000 mAh Battery with 80W Fast Charging                14
# 4500 mAh Battery with 44W Fast Charging                11
# 6000 mAh Battery with 15W Fast Charging                10
# 6000 mAh Battery with 25W Fast Charging                10
# 5000 mAh Battery with 120W Fast Charging               10
# 4500 mAh Battery with 25W Fast Charging                 9
# 3000 mAh Battery                                        8
# ...

# %%
df[(df['battery'] == '4.7 inches, 750 x 1334 px Display') | (df['battery'] == '6.1 inches, 1170 x 2532 px Display with Large Notch')]
# Out:
#                               model  price  rating  \
# 127                 Apple iPhone 12  53999    74.0
# 251         Apple iPhone 12 (128GB)  56990    75.0
# 321          Apple iPhone SE 3 2022  43900     NaN
# 489  Apple iPhone SE 3 2022 (256GB)  58900    61.0
# 490  Apple iPhone SE 3 2022 (128GB)  48900    61.0
# 515         Apple iPhone 12 (256GB)  66999    76.0
#
#                                          sim  \
# 127  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 251  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 489  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 490  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 515  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                   ram_rom  \
# 127    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 251    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# ...

# %%
# all columns from 'battery' onwards should shift to right
temp_df = df[(df['battery'] == '4.7 inches, 750 x 1334 px Display') | (df['battery'] == '6.1 inches, 1170 x 2532 px Display with Large Notch')]

# %%
shifted_values = temp_df.iloc[:,6:].shift(1,axis=1).values

# %%
df.loc[temp_df.index,temp_df.columns[6:]] = shifted_values

# %%
df.iloc[[127,251,321,489,490,515]]
# Out:
#                                        model  price  rating  \
# 127                          Apple iPhone 12  53999    74.0
# 251                  Apple iPhone 12 (128GB)  56990    75.0
# 321                   Apple iPhone SE 3 2022  43900     NaN
# 494  Xiaomi Redmi Note 11S (6GB RAM + 128GB)  15499    81.0
# 495          Xiaomi 11i 5G (8GB RAM + 128GB)  22690    83.0
# 520          Xiaomi Redmi 8 (4GB RAM + 64GB)  10990    66.0
#
#                                                 sim  \
# 127         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 251         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 494      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 495  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 520      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
#
#                                            processor  \
# 127         Bionic A14, Hexa Core, 3.1 GHz Processor
# 251         Bionic A14, Hexa Core, 3.1 GHz Processor
# ...

# %%
df['battery'].value_counts() # validity issue solved
# Out:
# 5000 mAh Battery with 33W Fast Charging      76
# 5000 mAh Battery                             75
# 5000 mAh Battery with 18W Fast Charging      61
# 5000 mAh Battery with 10W Fast Charging      46
# 5000 mAh Battery with 67W Fast Charging      27
# 5000 mAh Battery with 25W Fast Charging      26
# 6000 mAh Battery with 18W Fast Charging      23
# 4000 mAh Battery                             19
# 5000 mAh Battery with 15W Fast Charging      19
# 5000 mAh Battery with 80W Fast Charging      14
# 4500 mAh Battery with 44W Fast Charging      11
# 6000 mAh Battery with 15W Fast Charging      10
# 6000 mAh Battery with 25W Fast Charging      10
# 5000 mAh Battery with 120W Fast Charging     10
# 4500 mAh Battery with 25W Fast Charging       9
# 3000 mAh Battery                              8
# 5000 mAh Battery with 45W Fast Charging       8
# 5000 mAh Battery with 100W Fast Charging      7
# 5000 mAh Battery with 20W Fast Charging       7
# 5020 mAh Battery with 18W Fast Charging       7
# ...

# %%
df['display'].value_counts()
# Out:
# 6.5 inches, 720 x 1600 px Display with Water Drop Notch              42
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          42
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole           25
# 6.52 inches, 720 x 1600 px Display with Water Drop Notch             23
# 6.43 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole           18
# 6.53 inches, 720 x 1600 px Display with Water Drop Notch             17
# 6.51 inches, 720 x 1600 px Display with Water Drop Notch             12
# 6.6 inches, 1080 x 2408 px Display with Water Drop Notch             12
# 6.78 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          11
# 6.67 inches, 1080 x 2400 px Display with Punch Hole                  11
# 6.5 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            11
# 6.5 inches, 1600 x 720 px Display with Water Drop Notch              10
# 6.78 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole          10
# ...

# %%
df['camera'].value_counts() #validity issue - 'Dual Display' in 1 row. 'Foldable Display, Dual Display' in 13 rows.
                            # also consistency issue is there.
# Out:
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                 30
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                           25
# 8 MP Rear & 5 MP Front Camera                                        24
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                 21
# 50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                  18
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                           17
# 12 MP + 12 MP Dual Rear & 12 MP Front Camera                         16
# 13 MP Rear & 8 MP Front Camera                                       16
# 13 MP Rear & 5 MP Front Camera                                       16
# 48 MP Quad Rear & 16 MP Front Camera                                 14
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                 14
# Foldable Display, Dual Display                                       13
# 13 MP + 2 MP Dual Rear & 8 MP Front Camera                           12
# ...

# %%
df[(df['camera'] == 'Foldable Display, Dual Display') | (df['camera'] == 'Dual Display')]
# Out:
#                                           model   price  rating  \
# 149                     Samsung Galaxy Z Flip 5   99999    88.0
# 193                     Samsung Galaxy Z Flip 3   44999    83.0
# 266                      Motorola Razr 40 Ultra   89999    89.0
# 296  Samsung Galaxy Z Fold 5 (12GB RAM + 512GB)  164999     NaN
# 309    Samsung Galaxy Z Fold 5 (12GB RAM + 1TB)  184999     NaN
# 311                            Motorola Razr 40   59999    88.0
# 335                     Samsung Galaxy Z Fold 4  154999     NaN
# 350                        Tecno Phantom V Fold   88888     NaN
# 351                           OPPO Find N2 Flip   89999    88.0
# 411                     Samsung Galaxy Z Fold 3  110999    89.0
# 433                  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 522   Samsung Galaxy Z Flip 5 (8GB RAM + 512GB)  109999    88.0
# 574   Samsung Galaxy Z Flip 4 (8GB RAM + 256GB)   94999    88.0
# 646                           Unihertz TickTock   63999    85.0
#
# ...

# %%
temp_df = df[(df['camera'] == 'Foldable Display, Dual Display') | (df['camera'] == 'Dual Display')]

# %%
temp_df.iloc[:,8:].shift(-1,axis=1)
# Out:
#                                                 camera  \
# 149       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 193       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 266       13 MP + 12 MP Dual Rear & 32 MP Front Camera
# 296  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 309  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 311       64 MP + 13 MP Dual Rear & 32 MP Front Camera
# 335  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 350  50 MP + 50 MP + 13 MP Triple Rear & 32 MP + 16...
# 351        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 411  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 433       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 522       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 574       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 646                     48 MP Rear & 8 MP Front Camera
#
#                    memory_card operating_system
# 149  Memory Card Not Supported             None
# ...

# %%
temp_df.iloc[:,8:].shift(-1,axis=1).values
# Out:
# array([['12\u2009MP + 12\u2009MP Dual Rear & 10\u2009MP Front Camera',
#         'Memory Card Not Supported', None],
#        ['12\u2009MP + 12\u2009MP Dual Rear & 10\u2009MP Front Camera',
#         'Memory Card Not Supported', None],
#        ['13\u2009MP + 12\u2009MP Dual Rear & 32\u2009MP Front Camera',
#         'Memory Card Not Supported', None],
#        ['50\u2009MP + 12\u2009MP + 10\u2009MP Triple Rear & 10\u2009MP + 4\u2009MP Dual Front Camera',
#         'Android v13', None],
#        ['50\u2009MP + 12\u2009MP + 10\u2009MP Triple Rear & 10\u2009MP + 4\u2009MP Dual Front Camera',
#         'Android v13', None],
#        ['64\u2009MP + 13\u2009MP Dual Rear & 32\u2009MP Front Camera',
#         'Memory Card Not Supported', None],
#        ['50\u2009MP + 12\u2009MP + 10\u2009MP Triple Rear & 10\u2009MP + 4\u2009MP Dual Front Camera',
#         'Android v12', None],
#        ['50\u2009MP + 50\u2009MP + 13\u2009MP Triple Rear & 32\u2009MP + 16\u2009MP Dual Front Camera',
# ...

# %%
shifted_values = temp_df.iloc[:,8:].shift(-1,axis=1).values

# %%
df.loc[temp_df.index,temp_df.columns[8:]] = shifted_values

# %%
df['camera'].value_counts() # validity issue solved
# Out:
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   30
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                             25
# 8 MP Rear & 5 MP Front Camera                                          24
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   21
# 50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                    18
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                             17
# 12 MP + 12 MP Dual Rear & 12 MP Front Camera                           16
# 13 MP Rear & 5 MP Front Camera                                         16
# 13 MP Rear & 8 MP Front Camera                                         16
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                   14
# 48 MP Quad Rear & 16 MP Front Camera                                   14
# 13 MP + 2 MP Dual Rear & 8 MP Front Camera                             12
# 50 MP Dual Rear & 8 MP Front Camera                                    12
# ...

# %%
df['memory_card'].value_counts() # some rows contain 'operating_system' info.
# Out:
# Memory Card Supported, upto 1 TB      148
# Memory Card Supported, upto 512 GB    100
# Memory Card (Hybrid), upto 1 TB        83
# Memory Card Not Supported              79
# Memory Card Supported, upto 256 GB     57
# Android v12                            54
# Android v13                            41
# Memory Card Supported                  35
# Android v11                            17
# Memory Card (Hybrid)                   14
# Memory Card Supported, upto 128 GB     14
# Memory Card (Hybrid), upto 512 GB      13
# Memory Card Supported, upto 2 TB       12
# Memory Card (Hybrid), upto 128 GB       9
# Android v10                             9
# Memory Card (Hybrid), upto 256 GB       8
# Memory Card (Hybrid), upto 64 GB        4
# Android v8.1 (Oreo)                     2
# Memory Card Supported, upto 64 GB       2
# Android v9.0 (Pie)                      1
# Memory Card Supported, upto 32 GB       1
# Name: memory_card, dtype: int64

# %%
df[(df['memory_card'] == 'Android v12') |(df['memory_card'] == 'Android v13') | (df['memory_card'] == 'Android v11') | (df['memory_card'] == 'Android v10') | (df['memory_card'] == 'Android v8.1 (Oreo)') | (df['memory_card'] == 'Android v9.0 (Pie)')]
# Out:
#                                               model   price  rating  \
# 8                               Motorola Edge 40 5G   29999    87.0
# 10                                    Realme 11 Pro   23599    85.0
# 13                                OnePlus Nord 3 5G   32674    85.0
# 18                                   OnePlus 11R 5G   38684    85.0
# 19                                         Vivo V27   32799    85.0
# 23                      Xiaomi Redmi Note 12 Pro 5G   21993    79.0
# 32                                 OPPO Reno 10 Pro   39999    87.0
# 44                                   iQOO Neo 7 Pro   34999    83.0
# 56                                     Vivo V27 Pro   37999    84.0
# 57                                   Realme GT 2 5G   24999    84.0
# 61                                          Poco F5   26999    84.0
# 64                                   Lava Agni 2 5G   21999    82.0
# 67                                  Vivo V25 Pro 5G   27489    84.0
# ...

# %%
temp_df = df[(df['memory_card'] == 'Android v12') |(df['memory_card'] == 'Android v13') | (df['memory_card'] == 'Android v11') | (df['memory_card'] == 'Android v10') | (df['memory_card'] == 'Android v8.1 (Oreo)') | (df['memory_card'] == 'Android v9.0 (Pie)')]

# %%
shifted_df = temp_df.iloc[:,9:].shift(1,axis = 1).values

# %%
df.loc[temp_df.index,temp_df.columns[9:]] = shifted_df

# %%
df['memory_card'].value_counts() # validity issue solved
# Out:
# Memory Card Supported, upto 1 TB      148
# Memory Card Supported, upto 512 GB    100
# Memory Card (Hybrid), upto 1 TB        83
# Memory Card Not Supported              79
# Memory Card Supported, upto 256 GB     57
# Memory Card Supported                  35
# Memory Card (Hybrid)                   14
# Memory Card Supported, upto 128 GB     14
# Memory Card (Hybrid), upto 512 GB      13
# Memory Card Supported, upto 2 TB       12
# Memory Card (Hybrid), upto 128 GB       9
# Memory Card (Hybrid), upto 256 GB       8
# Memory Card (Hybrid), upto 64 GB        4
# Memory Card Supported, upto 64 GB       2
# Memory Card Supported, upto 32 GB       1
# Name: memory_card, dtype: int64

# %%
df['operating_system'].value_counts()
# Out:
# Android v12                  231
# Android v11                  167
# Android v13                  153
# Android v10                   56
# Android v10.0                 21
# Android v9.0 (Pie)            15
# iOS v16                       14
# iOS v15                       11
# Android v8.1 (Oreo)            9
# Android v11.0                  5
# iOS v14                        3
# iOS v15.0                      3
# iOS v13                        2
# Android                        2
# Android v7.0 (Nougat)          1
# Android v5.1.1 (Lollipop)      1
# Name: operating_system, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 703 entries, 0 to 708
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   model             703 non-null    object
#  1   price             703 non-null    int64
#  2   rating            633 non-null    float64
#  3   sim               703 non-null    object
#  4   processor         703 non-null    object
#  5   ram_rom           703 non-null    object
#  6   battery           697 non-null    object
#  7   display           703 non-null    object
#  8   camera            703 non-null    object
#  9   memory_card       579 non-null    object
#  10  operating_system  694 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 82.1+ KB

# %%
df.isnull().sum()
# Out:
# model                 0
# price                 0
# rating               70
# sim                   0
# processor             0
# ram_rom               0
# battery               6
# display               0
# camera                0
# memory_card         124
# operating_system      9
# dtype: int64

# %%
df['operating_system'].unique()
# Out:
# array(['Android v13', 'Android v11', 'Android v12', 'Android v10',
#        'iOS v15', 'iOS v16', 'iOS v13', 'iOS v14', None, 'Android v10.0',
#        'Android v11.0', 'Android v9.0 (Pie)', 'Android v8.1 (Oreo)',
#        'iOS v15.0', 'Android v7.0 (Nougat)', 'Android',
#        'Android v5.1.1 (Lollipop)'], dtype=object)

# %%
df[df['operating_system'].isnull()]
# Out:
#                                          model   price  rating  \
# 149                    Samsung Galaxy Z Flip 5   99999    88.0
# 193                    Samsung Galaxy Z Flip 3   44999    83.0
# 266                     Motorola Razr 40 Ultra   89999    89.0
# 311                           Motorola Razr 40   59999    88.0
# 351                          OPPO Find N2 Flip   89999    88.0
# 433                 Samsung Galaxy Z Flip 4 5G   89999    88.0
# 522  Samsung Galaxy Z Flip 5 (8GB RAM + 512GB)  109999    88.0
# 574  Samsung Galaxy Z Flip 4 (8GB RAM + 256GB)   94999    88.0
# 646                          Unihertz TickTock   63999    85.0
#
#                                                  sim  \
# 149  Single Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 193          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 266          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 311          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 351        Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
temp_df = df[df['operating_system'].isnull()]

# %%
values = np.array(['Android v13','Android v11','Android v13','Android v13','Android v13','Android v12','Android v13','Android v12','Android v11'])

# %%
values
# Out:
# array(['Android v13', 'Android v11', 'Android v13', 'Android v13',
#        'Android v13', 'Android v12', 'Android v13', 'Android v12',
#        'Android v11'], dtype='<U11')

# %%
df.loc[temp_df.index,'operating_system'] = values

# %%
df.isnull().sum()
# Out:
# model                 0
# price                 0
# rating               70
# sim                   0
# processor             0
# ram_rom               0
# battery               6
# display               0
# camera                0
# memory_card         124
# operating_system      0
# dtype: int64

# %%
df[df['memory_card'].isnull()]
# Out:
#                                               model   price  rating  \
# 8                               Motorola Edge 40 5G   29999    87.0
# 10                                    Realme 11 Pro   23599    85.0
# 13                                OnePlus Nord 3 5G   32674    85.0
# 18                                   OnePlus 11R 5G   38684    85.0
# 19                                         Vivo V27   32799    85.0
# 23                      Xiaomi Redmi Note 12 Pro 5G   21993    79.0
# 32                                 OPPO Reno 10 Pro   39999    87.0
# 44                                   iQOO Neo 7 Pro   34999    83.0
# 56                                     Vivo V27 Pro   37999    84.0
# 57                                   Realme GT 2 5G   24999    84.0
# 61                                          Poco F5   26999    84.0
# 64                                   Lava Agni 2 5G   21999    82.0
# 67                                  Vivo V25 Pro 5G   27489    84.0
# ...

# %%
temp_df = df[df['memory_card'].isnull()]

# %%
df.loc[temp_df.index,'memory_card'] = "Memory Card Not Supported"

# %%
df['memory_card'].value_counts()
# Out:
# Memory Card Not Supported             204
# Memory Card Supported, upto 1 TB      148
# Memory Card Supported, upto 512 GB    100
# Memory Card (Hybrid), upto 1 TB        83
# Memory Card Supported, upto 256 GB     57
# Memory Card Supported                  35
# Memory Card Supported, upto 128 GB     14
# Memory Card (Hybrid)                   13
# Memory Card (Hybrid), upto 512 GB      13
# Memory Card Supported, upto 2 TB       12
# Memory Card (Hybrid), upto 128 GB       9
# Memory Card (Hybrid), upto 256 GB       8
# Memory Card (Hybrid), upto 64 GB        4
# Memory Card Supported, upto 64 GB       2
# Memory Card Supported, upto 32 GB       1
# Name: memory_card, dtype: int64

# %%
df.isnull().sum()
# Out:
# model                0
# price                0
# rating              70
# sim                  0
# processor            0
# ram_rom              0
# battery              6
# display              0
# camera               0
# memory_card          0
# operating_system     0
# dtype: int64

# %%
df[df['battery'].isnull()]
# Out:
#                               model  price  rating  \
# 127                 Apple iPhone 12  53999    74.0
# 251         Apple iPhone 12 (128GB)  56990    75.0
# 321          Apple iPhone SE 3 2022  43900     NaN
# 489  Apple iPhone SE 3 2022 (256GB)  58900    61.0
# 490  Apple iPhone SE 3 2022 (128GB)  48900    61.0
# 515         Apple iPhone 12 (256GB)  66999    76.0
#
#                                          sim  \
# 127  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 251  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 489  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 490  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 515  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                   ram_rom  \
# 127    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 251    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# ...

# %%
values = (['2815 mAh Battery with 20W Fast Charging','2815 mAh Battery with 20W Fast Charging','2018 mAh Battery with 20W Fast Charging','1624 mAh Battery with 20W Fast Charging','1624 mAh Battery with 20W Fast Charging','2815 mAh Battery with 20W Fast Charging'])

# %%
values
# Out:
# ['2815 mAh Battery with 20W Fast Charging',
#  '2815 mAh Battery with 20W Fast Charging',
#  '2018 mAh Battery with 20W Fast Charging',
#  '1624 mAh Battery with 20W Fast Charging',
#  '1624 mAh Battery with 20W Fast Charging',
#  '2815 mAh Battery with 20W Fast Charging']

# %%
temp_df = df[df['battery'].isnull()]

# %%
df.loc[temp_df.index,'battery'] = values

# %%
df['battery'].value_counts()
# Out:
# 5000 mAh Battery with 33W Fast Charging      76
# 5000 mAh Battery                             75
# 5000 mAh Battery with 18W Fast Charging      61
# 5000 mAh Battery with 10W Fast Charging      46
# 5000 mAh Battery with 67W Fast Charging      27
# 5000 mAh Battery with 25W Fast Charging      26
# 6000 mAh Battery with 18W Fast Charging      23
# 4000 mAh Battery                             19
# 5000 mAh Battery with 15W Fast Charging      19
# 5000 mAh Battery with 80W Fast Charging      14
# 4500 mAh Battery with 44W Fast Charging      11
# 6000 mAh Battery with 15W Fast Charging      10
# 6000 mAh Battery with 25W Fast Charging      10
# 5000 mAh Battery with 120W Fast Charging     10
# 4500 mAh Battery with 25W Fast Charging       9
# 3000 mAh Battery                              8
# 5000 mAh Battery with 45W Fast Charging       8
# 5000 mAh Battery with 100W Fast Charging      7
# 5000 mAh Battery with 20W Fast Charging       7
# 5020 mAh Battery with 18W Fast Charging       7
# ...

# %%
df.isnull().sum() #missing values in battery also filled
# Out:
# model                0
# price                0
# rating              70
# sim                  0
# processor            0
# ram_rom              0
# battery              0
# display              0
# camera               0
# memory_card          0
# operating_system     0
# dtype: int64

# %%
df # all validity issues solved. Tidiness issues still remains.
# Out:
#                                                  model   price  rating  \
# 0                                   Xiaomi Redmi 12 5G   11999    75.0
# 1               Xiaomi Redmi 12 5G (6 GB RAM + 128 GB)   13499    77.0
# 2                 Xiaomi Redmi 12 5G (8GB RAM + 256GB)   15499    80.0
# 3                            OnePlus Nord CE 3 Lite 5G   19999    85.0
# 4                                Samsung Galaxy F34 5G   18999    83.0
# 5                                 OnePlus Nord CE 3 5G   26999    84.0
# 6                        Vivo T2x 5G (6GB RAM + 128GB)   13999    78.0
# 7                                           Realme C53    9999    75.0
# 8                                  Motorola Edge 40 5G   29999    87.0
# 9                                         OPPO Reno 10   32999    88.0
# 10                                       Realme 11 Pro   23599    85.0
# 11                            Samsung Galaxy S21 FE 5G   39999    87.0
# ...

# %%
df.to_csv('cleaned_data2.csv',index=False)
