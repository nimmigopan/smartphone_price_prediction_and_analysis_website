# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('scraped_data.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0                                   model    price  rating  \
# 0           0                      Xiaomi Redmi 12 5G  ₹11,999    75.0
# 1           1  Xiaomi Redmi 12 5G (6 GB RAM + 128 GB)  ₹13,499    77.0
# 2           2    Xiaomi Redmi 12 5G (8GB RAM + 256GB)  ₹15,499    80.0
# 3           3               OnePlus Nord CE 3 Lite 5G  ₹19,999    85.0
# 4           4                   Samsung Galaxy F34 5G  ₹18,999    83.0
#
#                                               sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                          processor                   ram_rom  \
# 0  Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor  4 GB RAM, 128 GB inbuilt
# 1  Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# ...

# %%
df.shape
# Out:
# (1020, 12)

# %%
df.drop(['Unnamed: 0'], axis=1,inplace = True)

# %%
df.head()
# Out:
#                                     model    price  rating  \
# 0                      Xiaomi Redmi 12 5G  ₹11,999    75.0
# 1  Xiaomi Redmi 12 5G (6 GB RAM + 128 GB)  ₹13,499    77.0
# 2    Xiaomi Redmi 12 5G (8GB RAM + 256GB)  ₹15,499    80.0
# 3               OnePlus Nord CE 3 Lite 5G  ₹19,999    85.0
# 4                   Samsung Galaxy F34 5G  ₹18,999    83.0
#
#                                               sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                          processor                   ram_rom  \
# 0  Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor  4 GB RAM, 128 GB inbuilt
# 1  Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# ...

# %% [markdown]
# ## DATA ACCESSING

# %%
df.info()

#missing values in rating,camera,card,os
#price,rating is in 'string'(object)... there are missing values in rating.. Pandas always convert missing values into float..
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   model             1020 non-null   object
#  1   price             1020 non-null   object
#  2   rating            639 non-null    float64
#  3   sim               1020 non-null   object
#  4   processor         1020 non-null   object
#  5   ram_rom           1020 non-null   object
#  6   battery           1020 non-null   object
#  7   display           1020 non-null   object
#  8   camera            1017 non-null   object
#  9   memory_card       958 non-null    object
#  10  operating_system  857 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.isnull().sum()
# Out:
# model                 0
# price                 0
# rating              381
# sim                   0
# processor             0
# ram_rom               0
# battery               0
# display               0
# camera                3
# memory_card          62
# operating_system    163
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 8

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1012, 11)

# %%
#'price' column
df['price'].str.replace('₹','')  #removing ₹
# Out:
# 0         11,999
# 1         13,499
# 2         15,499
# 3         19,999
# 4         18,999
# 5         26,999
# 6         13,999
# 7          9,999
# 8         29,999
# 9         32,999
# 10        23,599
# 11        39,999
# 12         9,999
# 13        32,674
# 14        27,599
# 15        21,999
# 16        18,999
# 17        17,999
# 18        38,684
# 19        32,799
# 20        12,999
# 21        16,999
# 22        14,999
# 23        21,993
# 24         9,999
# 25        26,683
# 26        29,999
# 27        10,999
# 28      1,06,500
# 29        13,990
# 30        16,999
# 31        28,999
# 32        39,999
# 33        17,699
# 34        13,699
# 35        61,999
# 36        16,999
# 37        19,989
# 38         1,393
# 39        28,999
# 40        54,799
# 41        15,999
# 42        20,999
# 43        11,999
# 44        68,999
# 45        34,999
# 46        15,999
# 47        29,599
# 48         8,499
# 49        18,999
# 50      1,27,999
# 51         1,499
# ...

# %%
df['price'].str.replace('₹','').str.replace(',','') #removing commas.. but still in 'string' format
# Out:
# 0        11999
# 1        13499
# 2        15499
# 3        19999
# 4        18999
# 5        26999
# 6        13999
# 7         9999
# 8        29999
# 9        32999
# 10       23599
# 11       39999
# 12        9999
# 13       32674
# 14       27599
# 15       21999
# 16       18999
# 17       17999
# 18       38684
# 19       32799
# 20       12999
# 21       16999
# 22       14999
# 23       21993
# 24        9999
# 25       26683
# 26       29999
# 27       10999
# 28      106500
# 29       13990
# 30       16999
# 31       28999
# 32       39999
# 33       17699
# 34       13699
# 35       61999
# 36       16999
# 37       19989
# 38        1393
# 39       28999
# 40       54799
# 41       15999
# 42       20999
# 43       11999
# 44       68999
# 45       34999
# 46       15999
# 47       29599
# 48        8499
# 49       18999
# 50      127999
# 51        1499
# 52        8999
# 53       20999
# 54        6999
# 55       13499
# 56       20999
# 57       14999
# ...

# %%
df['price'] = df['price'].str.replace('₹','').str.replace(',','').astype('int') # converting float to int

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1012 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   model             1012 non-null   object
#  1   price             1012 non-null   int32
#  2   rating            633 non-null    float64
#  3   sim               1012 non-null   object
#  4   processor         1012 non-null   object
#  5   ram_rom           1012 non-null   object
#  6   battery           1012 non-null   object
#  7   display           1012 non-null   object
#  8   camera            1009 non-null   object
#  9   memory_card       950 non-null    object
#  10  operating_system  849 non-null    object
# dtypes: float64(1), int32(1), object(9)
# memory usage: 90.9+ KB

# %%
#pd.set_option('display.max_rows', None)

df[df['price'] < 3500]        #observing phones below 3500, found that they are feature phones.
# since we are focusing on smartphones, ignore feature phones
# Out:
#                                     model  price  rating  \
# 38                  Jio Bharat K1 Karbonn   1393     NaN
# 51                          Jio Bharat V2   1499     NaN
# 206                          Nokia 106 4G   2199     NaN
# 277                         itel Circle 1   1499     NaN
# 278                     Nokia 110 4G 2023   3099     NaN
# 311                        Nokia 105 2023   1299     NaN
# 323                    Samsung Guru E1200   1150     NaN
# 327                        BlackZone Aura    886     NaN
# 340         Samsung Guru Music 2 Dual Sim   2475     NaN
# 386                          BlackZone F1   1599     NaN
# 387                        Itel Power 900   1999     NaN
# 389                    Motorola Moto A10e   1299     NaN
# 391                       Itel MagicX Pro   2599     NaN
# 434                          Nokia 215 4G   3249     NaN
# 437                       BlackZone Bijli   1283     NaN
# ...

# %%
df1 = df[df['price'] > 3500]

# %%
df[df['price'] > 3500].shape
# Out:
# (709, 11)

# %%
df1.to_csv('cleaned_data1.csv')
